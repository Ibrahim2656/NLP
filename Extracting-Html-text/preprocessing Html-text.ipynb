# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# %%
def preprocess_text(text):
    #convert text to lowercases
    text=text.lower()
    
    #Remove HTML tages
    text=re.sub('<[^<]+?>','',text)
    
    #Remove Special characters and digits
    text=re.sub(r'[^a-zA-Z\s]','',text)
    
    # Tokenizartion
    tokens=word_tokenize(text)
    
    #Remove Stopwords
    stop_words=set(stopwords.words('english'))
    filtered_tokens=[word for word in tokens if word not in stop_words]
    
    #lemmatization
    lemmatizer=WordNetLemmatizer()
    lemmatizer_token=[lemmatizer.lemmatize(word) for word in filtered_tokens]
    
    return lemmatizer_token

# %%
def get_unique_words(url):
    # Fetch HTML content
    response=requests.get(url)
    html_content=response.text
    
    #Parse HTML
    soup=BeautifulSoup(html_content,'html.parser')
    text=soup.get_text()
    print('text:\n',text,'\n')
    #Preprocess text
    preprocessed_text=preprocess_text(text)
    
    #Get unique words
    unique_words=set(preprocessed_text)
    
    return unique_words

# %%
url="https://blog.hubspot.com/marketing/what-is-a-blog"
unique_words=get_unique_words(url)
# Out:
# text:
#
#
# What's a Blog & Why You Need One
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Skip to content
#
#
#
#
#
#
#
#
# English
# : Select a language
#
#
#
#
#
#
#
#                 日本語
#
#
#
#
#                 Deutsch
#
#
#
#
#                 English
#
#
#
#
#                 Español
#
#
#
#
#                 Português
#
#
#
#
#                 Français
#
#
#
#
#
#
#     High Contrast
#
#
#
#
#
#
#
#       Log in
#
#
#
#
#
#     Start free or get a demo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
#
#
#
#         Search...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
#
#
# Blogs
# Trusted by business builders worldwide, the HubSpot Blogs are your number-one source for education and inspiration.
#
#
#
#
#
#
#
#
#
#
#
#         Marketing
#
#
#
# Resources and ideas to put modern marketers ahead of the curve
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
unique_words_3=[word for word in unique_words if len(word)>=3]

# %%
unique_words_2=[word for word in unique_words if len(word)<=2]

# %%
unique_words_2
# Out:
# ['he', 'u', 'ai', 'us', 'ad', 'x', 'th', 'oh', 'v', 'bb', 'cm']

# %%
unique_words_3
# Out:
# ['idea',
#  'wheel',
#  'youtube',
#  'relation',
#  'pro',
#  'conversation',
#  'establish',
#  'partner',
#  'squad',
#  'authority',
#  'history',
#  'system',
#  'link',
#  'grow',
#  'startup',
#  'try',
#  'excellent',
#  'significant',
#  'check',
#  'google',
#  'invoice',
#  'abroad',
#  'ebooks',
#  'email',
#  'titled',
#  'suite',
#  'straight',
#  'unsubscribe',
#  'whether',
#  'semrush',
#  'policy',
#  'wikipedia',
#  'least',
#  'considered',
#  'woman',
#  'listbased',
#  'anything',
#  'used',
#  'gross',
#  'food',
#  'give',
#  'online',
#  'portugus',
#  'oftentimes',
#  'campaign',
#  'expert',
#  'siteif',
#  'dec',
#  'according',
#  'robot',
#  'guide',
#  'similar',
#  'influencers',
#  'including',
#  'adding',
#  'develop',
#  'watch',
#  'opportunity',
#  'nowadays',
#  'owner',
#  'discovery',
#  'scan',
#  'course',
#  'day',
#  'research',
#  'effort',
#  'engaging',
#  'pursuit',
#  'easytouse',
#  'indepth',
#  'reinvent',
#  'copy',
#  'legal',
# ...
